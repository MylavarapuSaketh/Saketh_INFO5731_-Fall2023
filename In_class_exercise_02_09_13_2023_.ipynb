# %% [markdown]
# <a href="https://colab.research.google.com/github/MylavarapuSaketh/Saketh_INFO5731_Fall2023/blob/main/In_class_exercise_02_09_13_2023_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The second In-class-exercise (09/13/2023, 40 points in total)

# %% [markdown]
# Kindly use the provided .ipynb document to write your code or respond to the questions. Avoid generating a new file.
# Execute all the cells before your final submission.

# %% [markdown]
# This in-class exercise is due tomorrow September 14, 2023 at 11:59 PM. No late submissions will be considered.

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points): Describe an interesting research question (or practical question or something innovative) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %% [markdown]
# Question 2 (10 points): Write python code to collect 1000 data samples you discussed above.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:
From an Indian e-commerce website in India, I purchased an iPhone.I want to compile phone review data.
 I used BeautifulSoup and Requests, two Python tools, to obtain this data. Ive documented the processes I took to gather the data.
 I used the for loop to traverse over all the pages, using the requests Python library to retrieve the needed page.
 In order to determine the class names for the review titles and the complete content, I utilised the inspect element in the lovely soup data collection tool.
 I used a data frame to display the data.

'''
# Out:
# '\nPlease write you answer here:\nFrom an Indian e-commerce website in India, I purchased an iPhone.I want to compile phone review data.\n I used BeautifulSoup and Requests, two Python tools, to obtain this data. Ive documented the processes I took to gather the data.\n I used the for loop to traverse over all the pages, using the requests Python library to retrieve the needed page.\n In order to determine the class names for the review titles and the complete content, I utilised the inspect element in the lovely soup data collection tool.\n I used a data frame to display the data.\n\n'

# %%
# You code here (Please add comments in the code):
from bs4 import BeautifulSoup
import requests
import pandas
title = []
fullReview =[]
for i in range(70):
  URL = "https://www.flipkart.com/apple-iphone-14-pro-max-deep-purple-128-gb/p/itm5256789ae40c7?pid=MOBGHWFHCWHXRZZJ&lid=LSTMOBGHWFHCWHXRZZJ1FSXCM&marketplace=FLIPKART&q=iphone+14+pro+max&store=tyy%2F4io&srno=s_1_1&otracker=AS_Query_OrganicAutoSuggest_3_10_na_na_na&otracker1=AS_Query_OrganicAutoSuggest_3_10_na_na_na&fm=search-autosuggest&iid=b621bdd1-fc41-4e79-b36b-cdabde7c6dbf.MOBGHWFHCWHXRZZJ.SEARCH&ppt=sp&ppn=sp&ssid=zftqofo6kw0000001694887002895&qH=37e37d60a349d989" + str(i)
  webPage = requests.get(URL)
  beautifulSoup = BeautifulSoup(webPage.text, 'html.parser')
  title_text = beautifulSoup.find_all(class_='_2-N8zT')
  fullReview_text = beautifulSoup.find_all(class_='t-ZTKy')
  for ele1, ele2 in zip(title_text, fullReview_text):
      title.append(ele1.text)
      fullReview.append(ele2.text)
res = pandas.DataFrame(list(zip(title, fullReview)), columns =['Title', 'Full text review'])
res
# Out:
#                      Title                                   Full text review
# 0                Just wow!  Finally after long wait I got my 512 GB IPhone...
# 1                Excellent  Superb camera superb built quality, display be...
# 2                Fabulous!       Awsum Perfect product from apple 👍🏼READ MORE
# 3       Highly recommended                     Very nice 👌 Awesome 👌READ MORE
# 4                Brilliant  Bought 1TB pro Max .... Op product..... Delive...
# ..                     ...                                                ...
# 685      Worth every penny     Awesome camera quality. Just love it.READ MORE
# 686          Great product  Nothing to say about i phone 14 pro max Just A...
# 687  Mind-blowing purchase  King is here, it is really super se upar and f...
# 688               Terrific  Excellent iPhone most beautifully crafted and ...
# 689              Fabulous!  Finally, I got iPhone 14 Pro Max 512GB ( Deep ...
#
# [690 rows x 2 columns]

# %% [markdown]
# Question 3 (10 points): Write python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/), or ACM Digital Libraries (https://dl.acm.org/) with the keyword "information retrieval". The articles should be published in the last 10 years (2013-2023).
#
# The following information of the article needs to be collected:
#
# (1) Title
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
import requests
from bs4 import BeautifulSoup

# Function to scrape and print articles from a given URL
def scrape_articles(url):
    response = requests.get(url)  # Send a GET request to the URL
    soup = BeautifulSoup(response.text, 'html.parser')   # Use BeautifulSoup to extract the page's HTML content.
    articles = soup.find_all('div', class_='gs_ri')  # Locate and gather data for each article on the page.

  # Loop through the articles and extract the desired information
    for article in articles:
        title = article.find('h3', class_='gs_rt').text
        venue = article.find('div', class_='gs_a').text.split(' - ')[-1]
        year = article.find('div', class_='gs_a').text.split(' - ')[0]
        authors = article.find('div', class_='gs_a').text.split(' - ')[1]
        abstract = article.find('div', class_='gs_rs').text

        print("Title:", title)
        print("Venue:", venue)
        print("Year:", year)
        print("Authors:", authors)
        print("Abstract:", abstract)
        print("\n---\n")

# Loop through plenty of pages of results to get 1,000 articles.
articles_per_page = 10  # A page of Google Scholar normally shows 10 items.
total_articles = 1000

for page in range(0, total_articles, articles_per_page):
  # URL of Google Scholar search results
    page_url = f"https://scholar.google.com/scholar?hl=en&as_sdt=0%2C44&q=artificial+intelligence&oq={page}"
    scrape_articles(page_url)
# Out:
# Streaming output truncated to the last 5000 lines.
# Abstract: … intelligence into machines, which constitutes the original motivation of Artificial Intelligence
# (AI). … There are many definitions of artificial intelligence. In the Turing test, AI is defined as the …
#
# ---
#
# Title: [BOOK][B] Artificial intelligence
# Venue: books.google.com
# Year: MA Boden
# Authors: 1996
# Abstract: Artificial Intelligence is the study of how to build or program computers to enable them to do
# what minds can do. This volume discusses the ways in which computational ideas and …
#
# ---
#
# Title: [BOOK][B] Artificial intelligence
# Venue: books.google.com
# Year: EB Hunt
# Authors: 2014
# Abstract: Artificial Intelligence provides information pertinent to the fundamental aspects of artificial
# intelligence. This book presents the basic mathematical and computational approaches to …
#
# ---
#
# Title: [BOOK][B] Artificial intelligence a modern approach
# Venue: scholar.alaqsa.edu.ps
# ...

# %% [markdown]
# Question 4 (10 points):
#
# In this task, you are required to identify and utilize online tools for web scraping data from websites without the need for coding, with a specific focus on Parsehub. The objective is to gather data and save it in formats like CSV, Excel, or any other suitable file format.
#
# You have to mention an introduction to the tool which ever you prefer to use, steps to follow for web scrapping and the final output of the data collected.
#
# Upload a document (Word or PDF File) in the same repository and you can add the link in the ipynb file.

# %%
https://github.com/MylavarapuSaketh/Saketh_INFO5731_Fall2023/blob/main/Mylavarapu_Saketh_Exercise_02.pdf
